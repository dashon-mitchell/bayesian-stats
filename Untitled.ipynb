# %%
print("your mom")
# Out:
# your mom

# %%
import sunode

# %%
import numpy as np
import sunode
import sunode.wrappers.as_theano
import pymc3 as pm

times = np.arange(1900,1921,1)
lynx_data = np.array([
    4.0, 6.1, 9.8, 35.2, 59.4, 41.7, 19.0, 13.0, 8.3, 9.1, 7.4,
    8.0, 12.3, 19.5, 45.7, 51.1, 29.7, 15.8, 9.7, 10.1, 8.6
])
hare_data = np.array([
    30.0, 47.2, 70.2, 77.4, 36.3, 20.6, 18.1, 21.4, 22.0, 25.4,
    27.1, 40.3, 57.0, 76.6, 52.3, 19.5, 11.2, 7.6, 14.6, 16.2, 24.7
])
#We also define a function for the right-hand-side of the ODE::

# %%
def lotka_volterra(t, y, p):
    return {
        'hares': p.alpha * y.hares - p.beta * y.lynxes * y.hares,
        'lynxes': p.delta * y.hares * y.lynxes - p.gamma * y.lynxes,
    }
with pm.Model() as model:
    hares_start = pm.HalfNormal('hares_start', sd=50)
    lynx_start = pm.HalfNormal('lynx_start', sd=50)

    ratio = pm.Beta('ratio', alpha=0.5, beta=0.5)

    fixed_hares = pm.HalfNormal('fixed_hares', sd=50)
    fixed_lynx = pm.Deterministic('fixed_lynx', ratio * fixed_hares)

    period = pm.Gamma('period', mu=10, sd=1)
    freq = pm.Deterministic('freq', 2 * np.pi / period)

    log_speed_ratio = pm.Normal('log_speed_ratio', mu=0, sd=0.1)
    speed_ratio = np.exp(log_speed_ratio)

    # Compute the parameters of the ode based on our prior parameters
    alpha = pm.Deterministic('alpha', freq * speed_ratio * ratio)
    beta = pm.Deterministic('beta', freq * speed_ratio / fixed_hares)
    gamma = pm.Deterministic('gamma', freq / speed_ratio / ratio)
    delta = pm.Deterministic('delta', freq / speed_ratio / fixed_hares / ratio)
    with model:
        y0 = {
        # The initial number of hares is the random variable `hares_start`,
        # and it has shape (), so it is a scalar value.
        'hares': (hares_start, ()),
        'lynxes': (lynx_start, ()),
        }

    params = {
        'alpha': (alpha, ()),
        'beta': (beta, ()),
        'gamma': (gamma, ()),
        'delta': (delta, ()),
        # Parameters (or initial states) do not have to be random variables,
        # they can also be fixed numpy values. In this case the shape
        # is infered automatically. Sunode will not compute derivatives
        # with respect to fixed parameters or initial states.
        'unused_extra': np.zeros(5),
    }
    with model:
        from sunode.wrappers.as_theano import solve_ivp
        solution, *_ = solve_ivp(
            y0=y0,
            params=params,
            rhs=lotka_volterra,
            # The time points where we want to access the solution
            tvals=times,
            t0=times[0],
        )
    with model:
        # We can access the individual variables of the solution using the
        # variable names.
        pm.Deterministic('hares_mu', solution['hares'])
        pm.Deterministic('lynxes_mu', solution['lynxes'])

        sd = pm.HalfNormal('sd')
        pm.Lognormal('hares', mu=solution['hares'], sd=sd, observed=hare_data)
        pm.Lognormal('lynxes', mu=solution['lynxes'], sd=sd, observed=lynx_data)

# %%
with model:
    trace: pm.sample(tune=100, draws=100,chains=1,cores=1)
# Out:
# /tmp/ipykernel_9931/3134885165.py:2: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace: pm.sample(tune=100, draws=100,chains=1,cores=1)
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [sd, log_speed_ratio, period, fixed_hares, ratio, lynx_start, hares_start]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='200' class='' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:50<00:00 Sampling chain 0, 0 divergences]
#     </div>
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 1.51087e-32 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-38 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-38 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-37 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-36 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-35 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-34 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-33 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-32 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-31 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 1.51087e-32 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-38 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-38 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-37 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-36 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-35 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-34 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-33 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-32 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.44295e-31 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.78, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.78, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.95, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.95, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.46, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.46, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.12, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.63, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.63, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.07, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.5, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.5, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.05, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.46, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.46, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.08, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.47, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.47, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.07, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.85, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.85, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.04, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.56, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.56, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.05, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.3, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.3, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.06, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.31, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.31, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.02, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.42, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.42, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.04, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.74, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.74, mxstep steps taken before reaching tout.
#
# Sampling 1 chain for 100 tune and 100 draw iterations (100 + 100 draws total) took 50 seconds.
# The acceptance probability does not match the target. It is 0.9380563113126342, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
# %matplotlib inline
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pymc3 as pm
import theano

from pymc3.ode import DifferentialEquation
from scipy.integrate import odeint

plt.style.use("seaborn-darkgrid")
